# %% [markdown]
# # Making DSA Karyotype Plots

# %%
suppressMessages(library(karyoploteR))

# %%
dsa <- toGRanges("/mmfs1/gscratch/stergachislab/mhsohny/SMaHT/DSA/karyoploteR/DSA_COLO829BL_v3.0.0_sorted.txt")

options(repr.plot.width = 30, repr.plot.height = 30)
par(bg="white") # Make Background color white
#kp <- plotKaryotype(genome = dsa, plot.type=6, cex=1.5, chromosomes="all")
kp <- plotKaryotype(genome = dsa, plot.type=1, cex=1.5, chromosomes="all")
#kpAddCytobandLabels(kp)
#kpDataBackground(kp, data.panel=1, color = "Red")
#kpDataBackground(kp, data.panel=2, color = "Blue")
# Out:
# plot without title

# %%
#createRandomRegions(nregions=10000, length.mean = 1e6, mask=NA, non.overlapping = FALSE)
